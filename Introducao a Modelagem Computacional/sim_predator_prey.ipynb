# %%
import os

import numpy as np

import utils, odes

# %%
OUTPUT_DIR = ".local/simulations/Predator Prey"
CSV_FILE_PATH = os.path.join(OUTPUT_DIR, "simulation.csv")
PLOT_FILE_PATH = os.path.join(OUTPUT_DIR, "simulation.png")

# %%
os.makedirs(name=OUTPUT_DIR, exist_ok=True)

# %%
time_steps, state_history = utils.simulate(
    ode_system=odes.ode_predator_prey,
    initial_condition=np.array([ 10, 25 ]),
    delta_t=0.1,
    t_final=200,
    solver=utils.rk4,
    ode_system_kwargs={ 'a': 0.02, 'b': 0.02, 'r': 0.2, 'm': 0.5 }
)

# %%
utils.save_simulation(
    time_steps=time_steps,
    state_history=state_history,
    columns_labels=[ 'Py', 'Pr' ],
    file_path=CSV_FILE_PATH
)

# %%
utils.plot_simulation(
    time_steps=time_steps,
    state_history=state_history,
    xlabel="Tempo (Dias)",
    ylabel="Quantidade de Indivíduos",
    title="Modelo Predador Presa",
    columns_to_plot=[ 0, 1 ],
    columns_labels=[ 'Py', 'Pr' ],
    figure_path=PLOT_FILE_PATH
)
